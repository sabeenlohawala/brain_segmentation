# %%
import os
import glob

import numpy as np
import torch
from torchvision import transforms
import matplotlib.pyplot as plt

# %%
data_root_dir = "/om2/user/sabeen/nobrainer_data_norm"
data_dir = os.path.join(data_root_dir, "new_med_no_aug_51")

mode = 'train'
# Get a list of all the brain image files in the specified directory
images = sorted(glob.glob(f"{data_dir}/{mode}/brain*.npy"))

# Get a list of all the mask files in the specified directory
masks = sorted(glob.glob(f"{data_dir}/{mode}/mask*.npy"))

# %%
intensity_scale = transforms.ColorJitter(brightness=0.2,contrast=0.2)

# %%
idx = 115
image = torch.from_numpy(np.load(images[idx]))
mask = torch.from_numpy(np.load(masks[idx]))

# %%
plt.imshow(image.permute(1,2,0),cmap='gray')

# %%
plt.imshow((intensity_scale(image/255)*255).permute(1,2,0),cmap='gray')
